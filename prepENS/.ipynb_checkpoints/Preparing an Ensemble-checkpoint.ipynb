# %%
import requests
import logging
import urllib
import sys,os
sys.path.append(os.path.dirname(os.path.dirname(os.path.abspath('prepENS.py'))))
from pdbparser.pdbParser import pdbParser, pdbTitle
from pdbparser.writepdb import writeca
from pdbparser.clean_pdb import getca
from align.alignment import msa_clustal, getseq

# %%
query='Q7NDN8'
mer=5
altloc='A'
cwd='.'

# %%
class PDBInfo():
    def __init__(self,query,mer):
        self.query=query
        self.mer=mer
        self.result,self.refseq=self.get_pdbinfo()

    def get_pdbinfo(self):
        URLbase = ('http://www.uniprot.org/uniprot/')

        idparam = {
            'query': 'ID:{}'.format(self.query),
            'format': 'tab',
            'columns': 'database(PDB),sequence'
        }


        result1 = requests.get(URLbase,params=idparam).text
        if len(result1) > 0:
            pdbids,refseq=result1.split('\n')[1].split('\t')
            pdbids=['{}'.format(i) for i in pdbids.split(';') if len(i)>1]
            chainids={z.split(';')[1].strip():z.split(';')[4].split('=')[0].strip() for z in [i for i in urllib.urlopen(URLbase+query+'.txt').readlines() if i.startswith('DR   PDB;')] if z.split()[3]=='X-ray;'}
        else:
            logging.critical('Cannot retrive the information for query number %s' %(query))
            return(None,None)

        returninfo={}
        for pdb in pdbids:
            try:
                count=0
                try:
                    chains=chainids[pdb].split('/')
                except AttributeError:
                    continue
                nchain=len(chains)
                if nchain == self.mer:
                    returninfo[pdb]=[count+1,[chains]]
                elif nchain > self.mer:
                    if nchain % self.mer == 0:
                        newchains=[]
                        for chnr in xrange(0,nchain,self.mer):
                            newchains.append(chains[chnr:chnr+self.mer])
                            count=count+1
                        returninfo[pdb]=[count,newchains]
                    else:
                        logging.warning('Cannot process PDB id %s. It does not contain complete set' %pdb)
                        chainids.pop(pdb)
                        pdbids.remove(pdb)
                else:
                    logging.warning('Cannot process PDB id %s. It does not contain complete set' %pdb)
                    chainids.pop(pdb)
                    pdbids.remove(pdb)
            except KeyError:
                logging.warning('PDB ID %s has no chain information' %pdb)
                pdbids.remove(pdb)
        return(returninfo,refseq)

def downloadPDB(pdblist,mer,altloc,refseq,query,cwd):
    outseq=open(cwd+'/'+query+'_seq.txt','w')
    outresmap=open(cwd+'/'+query+'_residmap.txt','w')
    outseq.write('>refseq'+'\n'+refseq+'\n')
    for pdb in pdblist:
        urllib.urlretrieve('http://files.rcsb.org/download/%s.pdb' %pdb, cwd+'/'+pdb+'.pdb')
        #time.sleep(-1)                                                                                                                                                                                                           
        for mol in range(0,pdblist[pdb][0]):
            pdblines=open(cwd+'/'+pdb+'.pdb').readlines()
            if pdbTitle(pdblines) is True:
                pdblist.pop(pdb)
                logging.critical('PDB ID %s is a chimera, skipping this file' %pdb)
                continue
            else:
                coord=pdbParser(pdblines,pdb,mer,altloc,[pdblist[pdb][1][mol]])
                coord=getca(coord,altloc,[pdblist[pdb][1][mol]])
                writeca(coord,cwd+'/'+pdb+'_'+str(mol+1)+'.pdb')
                for ch in pdblist[pdb][1][mol]:
                    ca=getca(coord,altloc,ch)
                    seq,map=getseq(ca)
                    outseq.write('>'+pdb+'_'+str(mol+1)+'.pdb'+'|'+ch+'|'+'\n'+seq+'\n')
                    code,name,nr=zip(*map)
                    outresmap.write(cwd+'/'+pdb+'_'+str(mol+1)+'.pdb'+'|'+ch+'|'+'\n'+'-'.join([str(i) for i in nr])+'\n')
        os.remove(cwd+'/'+pdb+'.pdb')
    outseq.close()
    outresmap.close()

# %%
info=PDBInfo(query,mer)
downloadPDB(info.result,mer,altloc,info.refseq,query,cwd)
# Out:
# WARNING:root:Cannot process PDB id 3IGQ. It does not contain complete set
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# WARNING:root:Cleaning alternative locations if present
# WARNING:root:Default alternative location is A
# CRITICAL:root:PDB ID 4YEU is a chimera, skipping this file
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-8-2abf732fcc8d> in <module>()
#       1 info=PDBInfo(query,mer)
# ----> 2 downloadPDB(info.result,mer,altloc,info.refseq,query,cwd)
#
# <ipython-input-7-a55e909d00b0> in downloadPDB(pdblist, mer, altloc, refseq, query, cwd)
#      78                 code,name,nr=zip(*map)
#      79                 outresmap.write(cwd+'/'+pdb+'_'+str(mol+1)+'.pdb'+'|'+ch+'|'+'\n'+'-'.join([str(i) for i in nr])+'\n')
# ---> 80         os.remove(cwd+'/'+pdb+'.pdb')
#      81     outseq.close()
#      82     outresmap.close()
#
# OSError: [Errno 2] No such file or directory: './4YEU.pdb'

# %%
def msa(seqfile,resmap,query,cwd,clustalopath):
    outfile=cwd+'/'+query+'_msa.aln.fasta'
    seqfile=cwd+'/'+seqfile
    core,broken=msa_clustal(seqfile,resmap,outfile,clustalopath)
    return(core,broken)

# %%
clustalopath="/Users/cattibrie_fr/anaconda/anaconda/bin/clustalo"
core,broken=msa(query+'_seq.txt',query+'_residmap.txt',query,cwd,clustalopath)

# %%
for record in core:
    print record.seq
